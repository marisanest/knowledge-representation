# %%
import unittest
import sys
sys.path.append("..")
sys.path.append("../..")
from src.jacks_car_rental.environment import JacksCarRentalEnvironment
from src.jacks_car_rental.model import JacksCarRentalEnvironmentModel
from test.jacks_car_rental.environment import TestJacksCarRentalEnvironment 
from src.jacks_car_rental.mdp import JacksCarRentalEnvironmentMDP
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Environment

# %%
env = JacksCarRentalEnvironment()

# %%
env.reset()
# Out:
# (10, 4)

# %%
env.step(-5)
# Out:
# ((16, 5), 10, False, '')

# %%
env.step(0)
# Out:
# ((14, 2), 80, False, '')

# %%
env.reset(0)
# Out:
# (0, 0)

# %%
env.step(5)
# Out:
# ((3, 4), -10, False, '')

# %% [markdown]
# ## Test

# %%
unittest.TextTestRunner().run(unittest.TestLoader().loadTestsFromModule(TestJacksCarRentalEnvironment()))
# Out:
# ......
# ----------------------------------------------------------------------
# Ran 6 tests in 1.358s
#
# OK
# <unittest.runner.TextTestResult run=6 errors=0 failures=0>

# %% [markdown]
# ## MDP

# %%
mdp = JacksCarRentalEnvironmentMDP()

# %% [markdown]
# ## Policy Iteration

# %%
mdp.iterate_policy(theta=1)
# Out:
# INFO:root:start iteration
# INFO:root:start evaluation.
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:start improvement.
# INFO:root:start evaluation.
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:start improvement.
# INFO:root:start evaluation.
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:start improvement.
# INFO:root:start evaluation.
# INFO:root:evaluate...
# INFO:root:start improvement.
# INFO:root:start evaluation.
# INFO:root:evaluate...
# INFO:root:start improvement.
# INFO:root:start evaluation.
# INFO:root:evaluate...
# INFO:root:start improvement.
# INFO:root:start evaluation.
# INFO:root:evaluate...
# INFO:root:start improvement.
# INFO:root:start evaluation.
# INFO:root:evaluate...
# INFO:root:start improvement.
# INFO:root:start evaluation.
# INFO:root:evaluate...
# INFO:root:start improvement.
# INFO:root:start evaluation.
# INFO:root:evaluate...
# INFO:root:start improvement.

# %% [markdown]
# ### Plots

# %%
mdp.plot3d_over_states()

# %%
mdp.plot_policy()

# %% [markdown]
# ## Value Iteration

# %%
mdp.reset()

# %%
mdp.iterate_values(theta=1)
# Out:
# INFO:root:start iteration
# INFO:root:start evaluation.
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:evaluate...
# INFO:root:start improvement.

# %%
mdp.plot3d_over_states()

# %%
mdp.plot_policy()
